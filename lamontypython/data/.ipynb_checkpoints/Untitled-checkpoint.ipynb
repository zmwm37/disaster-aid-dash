# %%
import pandas as pd

# %%
pd.read_csv('county_president_winner.csv')
# Out:
#        year    state state_po county_name  county_fips        office  \
# 0      2000  ALABAMA       AL     AUTAUGA         1001     PRESIDENT
# 1      2000  ALABAMA       AL     BALDWIN         1003     PRESIDENT
# 2      2000  ALABAMA       AL     BARBOUR         1005     PRESIDENT
# 3      2000  ALABAMA       AL        BIBB         1007     PRESIDENT
# 4      2000  ALABAMA       AL      BLOUNT         1009     PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 18916  2020  WYOMING       WY  SWEETWATER        56037  US PRESIDENT
# 18917  2020  WYOMING       WY       TETON        56039  US PRESIDENT
# 18918  2020  WYOMING       WY       UINTA        56041  US PRESIDENT
# 18919  2020  WYOMING       WY    WASHAKIE        56043  US PRESIDENT
# 18920  2020  WYOMING       WY      WESTON        56045  US PRESIDENT
#
#                candidate       party  candidatevotes  totalvotes   version  \
# ...

# %%
pd.read_csv('countypres_2000-2020.csv')
